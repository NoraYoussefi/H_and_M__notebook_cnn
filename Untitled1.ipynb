# %% [markdown]
# <a href="https://colab.research.google.com/github/NoraYoussefi/H_and_M__notebook_cnn/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Presentation du Projet : **Deep Learning Image Classification for e-commerce product recommendation**
#
# ---
#
# Systeme de classification des produits d'ecommerce, cet competition est cree par la societe H&M, et qui a comme objectif la creation d'un systeme de recommendation des produits, dans notre on a creer un systeme de recommendation des produits en se basant sur la classification des images selon les categories, et recommender des produits qui sont similaire, Cette technique est autrement dit **Product Categorization**
#
# ---
# Ce Projet a ete realise par le binome:
# *   **Ahmed Mellouk**
# *   **Nora Youssefi**

# %% [markdown]
# # **1. Telechargement du dataset du kaggle**

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download h-and-m-personalized-fashion-recommendations
# Out:
# ...
# 100% 28.7G/28.7G [07:53<00:00, 79.2MB/s]
# 100% 28.7G/28.7G [07:53<00:00, 65.1MB/s]

# %%
! unzip h-and-m-personalized-fashion-recommendations.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: images/089/0890677001.jpg
#   inflating: images/089/0890677002.jpg
#   inflating: images/089/0890677004.jpg
#   inflating: images/089/0890683001.jpg
#   inflating: images/089/0890683002.jpg
#   inflating: images/089/0890684001.jpg
#   inflating: images/089/0890684002.jpg
#   inflating: images/089/0890686002.jpg
#   inflating: images/089/0890697001.jpg
#   inflating: images/089/0890697002.jpg
#   inflating: images/089/0890700001.jpg
#   inflating: images/089/0890717001.jpg
#   inflating: images/089/0890717002.jpg
#   inflating: images/089/0890717003.jpg
#   inflating: images/089/0890722001.jpg
#   inflating: images/089/0890722002.jpg
#   inflating: images/089/0890734001.jpg
#   inflating: images/089/0890734003.jpg
#   inflating: images/089/0890741001.jpg
#   inflating: images/089/0890745001.jpg
#   inflating: images/089/0890746001.jpg
#   inflating: images/089/0890766001.jpg
# ...

# %%
#Suppression du fichier .zip apres extraction
import os
os.remove("h-and-m-personalized-fashion-recommendations.zip")

# %% [markdown]
# # **2. Dataset Exploration**

# %% [markdown]
# L'objectif de cette partie est de mieux comprendre nos donnees brute, et detecter les observations qui peuvent influencer notre model negativement, et essayer de les traiter durant la partie du traitement.

# %% [markdown]
# ---
#
#
# Notre dataset initial, consiste de deux fichiers, **images** et **article.csv**.
#
#
# *   **images** contient des dossiers en ordre numeriques.
# *   **article.csv** est un fichier excel contenent les metadonnees des images.
#
#
#
# > ![image.png](data:image/png;base64,...)
#
#
#
#
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2.a - Exploration**

# %%
import PIL
import matplotlib.pyplot as plt
import pathlib

data_dir = pathlib.Path("images")
image_count = len(list(data_dir.glob('*/*.jpg')))
print("Nombre total d'image : ",image_count)
# Out:
# Nombre total d'image :  105100

# %% [markdown]
# #### **Description des images:**
# ---
# Tous les images sont des photographies professionels des produits (front facing & white background), avec des dimentions differentes    **( hauteur et largeur > 1000px )**.
#
#
#
# > Cette chose qui sera beneficiaire pour notre model, puisque les images sont de qualite identique.
#
#
# ---

# %%
product = list(data_dir.glob('014/*'))
PIL.Image.open(str(product[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1166x1750 at 0x7F40CFD75E10>

# %% [markdown]
# ---
#
#
# On Observe que les images sont de different dimensions, ce qui va necessiter une **normalisation** des images dans la partie traitement.
#
#
# ---

# %%
print("Dimension d'image :")
print(PIL.Image.open(str(product[0])).size)
print(PIL.Image.open(str(product[1])).size)
print(PIL.Image.open(str(product[2])).size)
# Out:
# Dimension d'image :
# (1166, 1750)
# (1166, 1750)
# (1166, 1750)

# %%
import pandas as pd
import numpy as np 

df = pd.read_csv("articles.csv")

df.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
# ...

# %% [markdown]
# ### **2.b Analyse des donnees**

# %% [markdown]
# ---
#
#
# ***Dans cette section, on va analyser nos donnees brutes et les structurer pour avoir une meilleur comprehension de ces donnees et detecter des problemes potentiel.***
#
#
# ---

# %% [markdown]
# Puisque notre objectif est la categorisation des produits, on s'interesse par l'image du produit et son categorie seulement.
#
#
# ---

# %%
labelled_images=pd.DataFrame()

#labelled_images dataset creation
labelled_images["image_path"]=df["article_id"]
labelled_images["category"]=df["product_group_name"]

labelled_images.head()
# Out:
#    image_path            category
# 0   108775015  Garment Upper body
# 1   108775044  Garment Upper body
# 2   108775051  Garment Upper body
# 3   110065001           Underwear
# 4   110065002           Underwear

# %%
#nombre de classe - 19
print("Nombre des categories (classes) initial est : ",len(set(labelled_images["category"])))
# Out:
# Nombre des categories (classes) initial est :  19

# %%
#nombre d'images
print("Nombre total des images : ", str(len(set(labelled_images["image_path"]))))
# Out:
# Nombre total des images :  105542

# %% [markdown]
# ---
#
#
# On observe qu'il y en a un tres grand desequilibre au niveau des donnees entre les classes, ce desequilibre qui a une influence negative sur la precision du model et auguemente la chance d'avoir un surapprentissage.
# Pour resoudre ce probleme, on va utiliser le:
#  ***sous-echantillonage*** ***(Undersampling)***.
#
# ---

# %%
print("Nombre de produit par categorie : ")
labelled_images["category"].value_counts()
# Out:
# Nombre de produit par categorie :
# Garment Upper body       42741
# Garment Lower body       19812
# Garment Full body        13292
# Accessories              11158
# Underwear                 5490
# Shoes                     5283
# Swimwear                  3127
# Socks & Tights            2442
# Nightwear                 1899
# Unknown                    121
# Underwear/nightwear         54
# Cosmetic                    49
# Bags                        25
# Items                       17
# Furniture                   13
# Garment and Shoe care        9
# Stationery                   5
# Interior textile             3
# Fun                          2
# Name: category, dtype: int64

# %%
print("On contruit un dataframe contenant le chemin des images et leurs categories : ")
#Path Changing
def imagePath(image):
  return "images/0"+str(image)[0:2]+"/0"+str(image)+".jpg"

labelled_images["image_path"]=labelled_images["image_path"].apply(imagePath)

labelled_images.head()
# Out:
# On contruit un dataframe contenant le chemin des images et leurs categories :
#                   image_path            category
# 0  images/010/0108775015.jpg  Garment Upper body
# 1  images/010/0108775044.jpg  Garment Upper body
# 2  images/010/0108775051.jpg  Garment Upper body
# 3  images/011/0110065001.jpg           Underwear
# 4  images/011/0110065002.jpg           Underwear

# %% [markdown]
# ### **2.c Groupement des images par classe**

# %% [markdown]
# ---
#
#
# Dans cet partie, on va creer une nouvelle dataset, suivant la forme suivante:
#
#
#
# > ![image.png](data:image/png;base64,...)
#
#
#
# Chaque dossier dans cette dataset, represente une classe, qui contient tous les images qui appartient a la meme classe,
# ce traitement va simplifier la manipulation des donsees
#
#
#
# ---

# %%
import shutil,os

#Construction du nouvelle dataset, dont chaque dossier va representer une classe.
for index, row in labelled_images.iterrows():
  if not os.path.exists("dataset/"+row['category']):
    os.makedirs("dataset/"+row['category']) #Creation du repertoire

  if os.path.exists(row['image_path']):
    shutil.copy2(row['image_path'],"dataset/"+row['category']) #Copier les images dans le dossier

# %%
shutil.rmtree("images") #Suppression de dossier images

# %% [markdown]
# ### **2.d Visualization**

# %% [markdown]
# ---
#
#
# On visualise la distribution des images au niveaux des differents classes.
#
#
#
# > On observe que la classe **Garment Upper body** represente plus de **40%** de notre dataset.
#
# > La classe **Fun** qui represente presque **0%** du dataset, meme si il contient des images.
#
#
#
# Cela signifie qu'il y'en un grand desequilibre dans les donnees, ce qui va necessiter un **sous-echantillonage** ***(Undersampling)***dans notre cas.
#
#
# ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os


labels = os.listdir("dataset")
sizes = []
for folder in labels:
  sizes.append(len(os.listdir("dataset/"+folder)))

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',startangle=90)
ax1.axis('equal')  

plt.show()

# %% [markdown]
# ---
#
#
# > On voit qu'il y en a une grande difference entre le nombre des produits dans chaque classe, ce déséquilibre qui va influencer negativement la precision du model et augmenter les chances de sur-apprentissage.
#
#
#
# > Pour notre cas, on va traiter ce desiquilbre en deux etapes:
# 1. ***Fusion des classes similaires***
# 2. ***Sous-echantillonage (Undersampling)***
#
#
#
#
#
#
# ---

# %%
plt.bar(labels, sizes)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **4. Traitement des donnees (Preprocessing)**

# %% [markdown]
# ## 4.1 Fusion des classes similaires

# %%
print("Etat de classes avant fusionnement : ")
labelled_images["category"].value_counts()
# Out:
# Etat de classes avant fusionnement :
# Garment Upper body       42741
# Garment Lower body       19812
# Garment Full body        13292
# Accessories              11158
# Underwear                 5490
# Shoes                     5283
# Swimwear                  3127
# Socks & Tights            2442
# Nightwear                 1899
# Unknown                    121
# Underwear/nightwear         54
# Cosmetic                    49
# Bags                        25
# Items                       17
# Furniture                   13
# Garment and Shoe care        9
# Stationery                   5
# Interior textile             3
# Fun                          2
# Name: category, dtype: int64

# %% [markdown]
# ---
#
#
# Dans cet etape, on vise a combiner les classes qui sont plus au moins similaire dans une seul classe qu'on va nommer **Accessories**, pour de simplifier de resoudre le probleme de manque des donnees au niveau de certain classe.
#
#
#
#
# > ![image.png](data:image/png;base64,...)
#
#
#
#
#
# ---

# %%
labels_to_combine=["Unknown","Underwear/nightwear","Cosmetic","Bags","Items","Furniture","Garment and Shoe care","Garment and Shoe care","Interior textile","Fun","Stationery"]

for labels in labels_to_combine:
  for image in os.listdir("dataset/"+labels):
    
    #On deplace les fichiers vers la classe Accessoirs
    os.replace("dataset/"+labels+"/"+image,"dataset/Accessories/"+image)
  
#On supprime les dossiers des classes fusionne
for labels in labels_to_combine:
  if os.path.exists("dataset/"+labels):
    shutil.rmtree("dataset/"+labels)

# %%
new_classes=os.listdir("dataset")
new_counts=[]
for label in new_classes:
  new_counts.append(len(os.listdir("dataset/"+label)))

print("Nombre d'image par classe apres fusionnement est :")
for i in range(len(new_classes)):
  print(new_classes[i]," : ",new_counts[i])
# Out:
# Nombre d'image par classe apres fusionnement est :
# Underwear  :  5462
# Swimwear  :  3125
# Shoes  :  5156
# Nightwear  :  1898
# Garment Lower body  :  19770
# Accessories  :  11302
# Garment Full body  :  13276
# Socks & Tights  :  2431
# Garment Upper body  :  42680

# %% [markdown]
# ## 4.2 Sous-echantillonage (Undersampling)

# %%
fig2, ax2 = plt.subplots()
ax2.pie(new_counts, labels=new_classes, autopct='%1.1f%%',startangle=90)
ax2.axis('equal')  

plt.show()

# %%
plt.bar(new_classes, new_counts)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ---
#
#
# *On voit que le nombre des classes est reduit, mais ca existe encore un grand desequilibre au niveau du donnees, ce qui necessite un sous-echantillonage (Undersamling)*.
#
#
#
# > **Notre approche sera tous simplement la suppression des images dans les classes dominants, on va supprimer juqu'au tous les classes possedent un maximum de 5000 images.**
#
#
#
# ---

# %%
import os

#Classes majorantes
large_datasets=["Garment Upper body","Garment Full body","Accessories","Garment Lower body"]

for large in large_datasets:
  if os.path.exists("dataset/"+large):
    files=os.listdir("dataset/"+large)

    for image in files:
      if len(os.listdir("dataset/"+large))>5000: #On supprime des images jusqu'a chaque classe contient un max de 5000 
        os.remove("dataset/"+large+"/"+image)

# %%
new_classes=os.listdir("dataset")
new_counts=[]
for label in new_classes:
  new_counts.append(len(os.listdir("dataset/"+label)))

for i in range(len(new_classes)):
  print(new_classes[i]," : ",new_counts[i])
# Out:
# Underwear  :  5462
# Swimwear  :  3125
# Shoes  :  5156
# Nightwear  :  1898
# Garment Lower body  :  5000
# Accessories  :  5000
# Garment Full body  :  5000
# Socks & Tights  :  2431
# Garment Upper body  :  5000

# %%
if os.path.exists("dataset/.ipynb_checkpoints"):
  os.remove("dataset/.ipynb_checkpoints")

# %% [markdown]
# ---
#
#
#
#
# > **Distribution apres sous-echantillonage**
#
#
#
#
# ---

# %%
fig2, ax2 = plt.subplots()
ax2.pie(new_counts, labels=new_classes, autopct='%1.1f%%',startangle=90)
ax2.axis('equal')  

plt.show()

# %% [markdown]
# ---
#
# **On voit que les classes sont plus au moins equilibree, ce qui va ameliorer notre modele et diminuer les chances d'avoir un overfitting.**
#
# ---

# %% [markdown]
# # **5. Train test split**

# %% [markdown]
# ---
#
#
# **Dans cette section, on vise a separer nos donnees en deux partie:**
#
# *   **Entrainement**
# *   **Evaluation**
#
# Pour faire ca, on se base sur la librairie **keras**, plus exactement le methode:
# ***tf.keras.utils.image_dataset_from_directory***
#
# ***Cette methode nous permet de :***
#
#
# 1.   Generer la dataset du training et testing
# 2.   Diviser le training et testing data en batch avec une taille qu'on specifie
# 3.   Faire le **Encoding** des classes, qui sont les noms des sous-dossiers du dossier **dataset**
#
#
#
#
# ---

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
batch_size = 32 #Nombre d'image par sous-echantillon des donnees d'entrainement et testing
img_height = 180 #Hauteur d'image apres resizing
img_width = 180 #Largeur d'image apres resizing

# %%
import pathlib
print("Training data : ")
train_ds = tf.keras.utils.image_dataset_from_directory(
  "dataset", #dossier contenant les classes et leurs images
  validation_split=0.2, #pourcentage de donnees pour validation 
  subset="training", #Specifier que cette data est pour l'entrainement
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Training data :
# Found 38072 files belonging to 9 classes.
# Using 30458 files for training.

# %%
print("Testing data : ")
val_ds = tf.keras.utils.image_dataset_from_directory(
  "dataset",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Testing data :
# Found 38072 files belonging to 9 classes.
# Using 7614 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Accessories', 'Garment Full body', 'Garment Lower body', 'Garment Upper body', 'Nightwear', 'Shoes', 'Socks & Tights', 'Swimwear', 'Underwear']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# # **5. Standarization**

# %% [markdown]
# ---
#
#
# **Dans cette section, on s'interesse par normaliser les images, afin de faire ca, on va diviser la matrice d'image par 255.**
#
# **Puisque chaque pixel value de notre matrice d'image est comprise entre 0 et 255 (RGB), Pour la normaliser on la divise par 255.**
#
#
# > **Le resultat est que chaque image se convertit a une matrice des pixel comprises entre 0 et 1.**
#
#
#
# ---

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.17641416 0.9399995

# %% [markdown]
# # **6. Reseau Neuronal Convultif (CNN)**

# %% [markdown]
# ---
#
#
# Un réseau neuronal convolutif est une classe de réseaux neuronaux spécialisés dans le traitement de données ayant une topologie en forme de grille, telle qu'une image. Une image numérique est une représentation binaire de données visuelles.
#
#
#
#
#
# ---

# %% [markdown]
# ### **6.1 Architecture du Reseau :**
#
# Notre reseau est construit par les couches suivants:
#
#
#
#
# *   3 couches de convolution (filtrage d'image)
# *   3 couches de maxpooling (Reduction de dimensions)
# *   1 couche pour transformer la matrice 2D d'output en list 1D
# *   1 couche Dense, represente les classes des images input.
#
#
#
# > ![image.png](data:image/png;base64,...)

# %%
num_classes = len(class_names)

model = Sequential([
  # data_augmentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), #couche pour normalisation
  
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  
  layers.Flatten(),

  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)

])

# %% [markdown]
# Pour l'optimizer, on a choisit Adam Optimizer

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_5 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_15 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_16 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 30976)             0
#
#  dense_10 (Dense)            (None, 128)               3965056
#
#  dense_11 (Dense)            (None, 9)                 1161
#
# ...
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **6.2 Apprentissage**

# %%
epochs=5 #Iteration sur dataset complete
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 952/952 [==============================] - 1354s 1s/step - loss: 1.0337 - accuracy: 0.6606 - val_loss: 0.7026 - val_accuracy: 0.7734
# Epoch 2/5
# 952/952 [==============================] - 1334s 1s/step - loss: 0.5642 - accuracy: 0.8187 - val_loss: 0.6051 - val_accuracy: 0.8021
# Epoch 3/5
# 952/952 [==============================] - 1329s 1s/step - loss: 0.3584 - accuracy: 0.8839 - val_loss: 0.6591 - val_accuracy: 0.8068
# Epoch 4/5
# 952/952 [==============================] - 1323s 1s/step - loss: 0.2136 - accuracy: 0.9307 - val_loss: 0.9345 - val_accuracy: 0.7993
# Epoch 5/5
# 952/952 [==============================] - 1322s 1s/step - loss: 0.1372 - accuracy: 0.9568 - val_loss: 1.0475 - val_accuracy: 0.7980

# %% [markdown]
# # **7. Evaluation**

# %% [markdown]
# ---
#
#
#
#
# On observe que notre modele a des precisions d'apprentissage et d'evaluation de proche valeurs:
#
#
#
# > **Training accuracy** : ***0.9826***
#
# > **Evaluation accuracy** : ***0.7977***
#
# La similarite entre les deux precisions signifie la bonne conception du modele et que notre modele a bien performe au niveau d'evaluation.
#
# Ce bon performance qui est grace au etape precedent du traitement des donnees (normalisation, sous-echantillonage, etc)
#
#
#
# ---

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Accuracy d'apprentissage")
plt.plot(epochs_range, val_acc, label="Accuracy de validation")
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Perte d'apprentissage")
plt.plot(epochs_range, val_loss, label="Perte d'evaluation")
plt.legend(loc='upper right')
plt.title("Perte d'apprentissage et d'evaluation ")
plt.show()
